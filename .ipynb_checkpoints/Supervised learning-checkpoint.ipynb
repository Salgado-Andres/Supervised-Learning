# %% [markdown]
# # Supervised learning with SCIKIT-LEARN

# %% [markdown]
# ## What is machine learning?
# __The art and science of:__
# - Giving computers the ability to learn to make decisions from data
# -  without being explictly programmed!
#
# __Examples__
#   -  Learning to predict whether an email is spam or not (Supervised)
#   -  Clustering wikipedia entries into different categories (Unsupervised)

# %% [markdown]
# ## Unsupervised learning
#   -  Uncovering hidden patterns from unlabeled data
#   -  Example:
#       -  Grouping customers into distinct categories( Clustering )

# %% [markdown]
# ## Reinforcement learning
#   -  Software agents interact with an enviroment
#         -  Learn how to optimize their behavior
#         -  Given a system of rewards and punishments
#   -  Applications
#       - Economics
#       - Genetics
#       - Game playing
#   -  AlphaGo: First computer to defeat the world champion at GO

# %% [markdown]
# ## Supervised learning
#   -  Predictor variables/features and a target variable
#   -  Aim: Predict the target variable, given the predictor variables
#         -  Classification: Target variable consists of categories
#         -  Regression: Target variable is continuous
#   -  Automate time-consuming or expensive manual tasks
#         -  Example:Doctor's diagnosis
#   -  Make predictions about the future
#         -  Example: Will a customer click on an ad or not?
#   -  Need labeled data
#         -  Historical data with labels
#         -  Experiments to get labeled data
#         -  Crowd-sourcing labeled data
#   - We will use scikit-learn/sklearn
#       - Integrates well with the SciPy stack
#   ![Supervised learning](Images/Supervisedlearning.png)

# %% [markdown]
# ## Naming conventions
#   -  Features = predictor variables = independent variables
#   -  Target variable = dependent variable = response variable

# %% [markdown]
# # Exploratory data analysis
#
#
#   ![Supervised learning](Images/Irisdataset.png)

# %% [markdown]
#    __Features:__
#     - Petal length
#     - Petal width
#     - sepal length
#     - sepal width
#
#    __Target variable:Species__
#    - Versicolor
#    - Virginica
#     - Setosa

# %% [markdown]
# ## the Iris dataset in scikit-learn

# %%
from sklearn import datasets

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')

iris = datasets.load_iris()
# We can see the type
type(iris)
# Out:
# sklearn.utils.Bunch

# %%
#print the keys
print(iris.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
#feature and data are arrays
type(iris.data), type(iris.target)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
#150 predictors variables 4 targets
iris.data.shape
# Out:
# (150, 4)

# %%
#Target outcome
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ## Exploratory data analysis (EDA)

# %%
x=iris.data
y=iris.target
df=pd.DataFrame(x, columns=iris.feature_names)
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ## Visual EDA

# %%
_ = pd.plotting.scatter_matrix(df, c = y, figsize = [7,7], marker = 'D' )
